# %%
import pandas as pd

# %%
data = pd.read_csv("data/train_set/movement_data_train/movement_train_set_1.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                            student_id    end_date  is_dropout  \
# 0        7774  f97d6608-520c-11ed-8170-005056bc2da6  2023-08-01           0
# 1        6743  da3404a0-52c4-11ed-8170-005056bc2da6  2023-08-01           0
# 2        1467  2a61c1e3-5232-11ed-8170-005056bc2da6  2023-08-01           0
# 3        2927  570d3b6e-52c3-11ed-8170-005056bc2da6  2023-08-01           0
# 4        6192  ca11c4b0-5233-11ed-8170-005056bc2da6  2023-08-01           0
#
#          level                department education_form spec_code  \
# 0  Специалитет  Филологический факультет          Очная  52.05.04
# 1  Бакалавриат                       ФТФ          Очная  16.03.01
# 2  Бакалавриат                       ММФ          Очная  01.03.01
# 3  Бакалавриат                        ЮИ          Очная  40.03.01
# 4  Бакалавриат                        ЮИ          Очная  40.03.01
#
#                                              profile  \
# 0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6405 entries, 0 to 6404
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    6405 non-null   int64
#  1   student_id                    6405 non-null   object
#  2   end_date                      6405 non-null   object
#  3   is_dropout                    6405 non-null   int64
#  4   level                         6405 non-null   object
#  5   department                    6405 non-null   object
#  6   education_form                6405 non-null   object
#  7   spec_code                     6405 non-null   object
#  8   profile                       6405 non-null   object
#  9   financing                     6405 non-null   object
#  10  edu_year                      6405 non-null   int64
#  11  dropout_count                 6405 non-null   int64
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'student_id', 'end_date', 'is_dropout', 'level',
#        'department', 'education_form', 'spec_code', 'profile', 'financing',
#        'edu_year', 'dropout_count', 'events_count', 'events', 'last_event',
#        'id', 'start_date_month', 'start_date_day', 'global_start_date_month',
#        'global_start_date_day', 'most_visited', 'most_visited_freq',
#        'freq_academic_building', 'freq_cultural_centre', 'freq_library',
#        'freq_main_building', 'freq_sport_complex',
#        'total_time_academic_building', 'total_time_cultural_center',
#        'total_time_library', 'total_time_main_building', 'total_time_sport'],
#       dtype='object')

# %%
data[['most_visited', 'most_visited_freq']].head()
# Out:
#         most_visited  most_visited_freq
# 0  Academic Building                330
# 1  Academic Building                772
# 2  Academic Building                482
# 3  Academic Building                209
# 4  Academic Building                680
